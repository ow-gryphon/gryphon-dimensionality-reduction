# %% [markdown]
# <div class="alert alert-danger" role="alert">
#     <span style="font-size:20px">&#9888;</span> <span style="font-size:16px">This is a read-only notebook! If you want to make and save changes, save a copy by clicking on <b>File</b> &#8594; <b>Save a copy</b>. If this is already a copy, you can delete this cell.</span>
# </div>

# %% [markdown]
# <h1>Variable Clustering<span class="tocSkip"></span></h1>
#
# This notebook provides a simple wrapper function to scipy's hierarchical clustering algorithm: https://docs.scipy.org/doc/scipy/reference/cluster.hierarchy.html
#
# **The code for this template was adapted from SQUAD's Sphinx tool for Clustering analysis: https://owlabs.atlassian.net/wiki/spaces/SQUADSPHINX/overview**

# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <ul class="toc-item"><li><span><a href="#Read-in-data" data-toc-modified-id="Read-in-data-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Read in data</a></span></li><li><span><a href="#Run-Variable-Clustering" data-toc-modified-id="Run-Variable-Clustering-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Run Variable Clustering</a></span></li></ul>

# %% [markdown]
# **We begin by importing key libraries for data handling and exploration**

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
import pandas as pd

# %%
# Developer's code to automatically update functions sourced in from the modules
# %load_ext autoreload
# %autoreload 2

# Add path of the folder 'resources' to the path from which we can import modules  
import sys
sys.path.append('../../utilities')

# %% [markdown]
# # Read in data
#
# This dataset contains soccer player attributes from the FIFA soccer game.

# %%
# Load in the data
soccer_data = pd.read_csv("sample_input/soccer.csv")
soccer_data.head()
# Out:
#    player_api_id        player_name  overall_rating  potential  crossing  \
# 0           2625  Patryk Rachwal,18            60.5       61.0      50.0
# 1           2752        Diego Mainz            70.0       71.0      36.0
# 2           2768        Jose Dorado            72.0       73.0      42.0
# 3           2770   Ignacio Gonzalez            71.0       72.0      62.0
# 4           2790        Alberto Rey            71.0       76.0      71.0
#
#    finishing  heading_accuracy  short_passing  volleys  dribbling  ...  \
# 0       47.0              46.0           53.0     38.0       56.0  ...
# 1       37.0              72.0           55.0     20.0       45.0  ...
# 2       42.0              69.0           68.0     28.0       39.0  ...
# 3       68.0              71.0           72.0     69.0       71.0  ...
# 4       37.0              55.0           68.0     43.0       64.0  ...
#
#    fix_vision  fix_penalties  fix_marking  fix_standing_tackle  \
# 0    4.060606      15.060606    12.060606            12.060606
# 1    8.030303      -8.969697    30.030303            29.030303
# 2    9.090909     -22.909091    26.090909            25.090909
# 3   18.424242      14.424242   -21.575758           -11.575758
# 4    2.242424      -3.757576    19.242424            19.242424
#
#    fix_sliding_tackle  fix_gk_diving  fix_gk_handling  fix_gk_kicking  \
# 0            3.060606     -38.939394       -39.939394      -44.939394
# 1           21.030303     -32.969697       -37.969697      -36.969697
# 2           33.090909     -36.909091       -33.909091      -35.909091
# 3          -29.575758     -42.575758       -41.575758      -48.575758
# 4           11.242424     -49.757576       -36.757576       13.242424
#
#    fix_gk_positioning  fix_gk_reflexes
# 0          -42.939394       -42.939394
# 1          -34.969697       -28.969697
# 2          -34.909091       -38.909091
# 3          -40.575758       -39.575758
# 4          -36.757576       -36.757576
#
# [5 rows x 83 columns]

# %% [markdown]
# # Run Variable Clustering
#
# We use the euclidean distance to calculate the similarity of these variables, and also standardize the variable. Since the variables are already taken from the same 0 to 100 scale, and has been de-meaned, we do not need to standardize the variables

# %%
from dimensionality_reduction import agglomerative_feature_clustering

variable_names = [
    'fix_crossing', 'fix_short_passing', 'fix_finishing', 'fix_volleys', 'fix_heading_accuracy', 'fix_dribbling', 'fix_curve', 'fix_free_kick_accuracy',
    'fix_long_passing', 'fix_ball_control', 'fix_acceleration', 'fix_sprint_speed', 'fix_agility', 'fix_reactions', 'fix_balance', 'fix_shot_power', 'fix_jumping',
    'fix_stamina', 'fix_strength', 'fix_long_shots', 'fix_aggression', 'fix_interceptions', 'fix_positioning', 'fix_vision', 'fix_penalties', 'fix_marking',
    'fix_standing_tackle', 'fix_sliding_tackle', 'fix_gk_diving', 'fix_gk_handling', 'fix_gk_kicking', 'fix_gk_positioning', 'fix_gk_reflexes'
]

output = agglomerative_feature_clustering.run_variable_cluster(
    data=soccer_data,
    variables=variable_names,
    distance_metric='euclidean',
    standardize_vars=False,
    generate_charts=True,
    save_results_to_excel=True
)
# Out:
# Running basic numerical hierarchical clustering
# End Agglo Feature Clustering

# %% [markdown]
# **You can double click on the image above to zoom in**
